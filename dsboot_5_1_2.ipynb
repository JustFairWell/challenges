# %%
import pandas as pd
import numpy as np
import random

# %%
def quickSort(alist):
   quickSortHelper(alist,0,len(alist)-1)

def quickSortHelper(alist,first,last):
   if first<last:

       splitpoint = partition(alist,first,last)

       quickSortHelper(alist,first,splitpoint-1)
       quickSortHelper(alist,splitpoint+1,last)


def partition(alist,first,last):
   pivotvalue = alist[first]

   leftmark = first+1
   rightmark = last

   done = False
   while not done:

       while leftmark <= rightmark and alist[leftmark] <= pivotvalue:
           leftmark = leftmark + 1

       while alist[rightmark] >= pivotvalue and rightmark >= leftmark:
           rightmark = rightmark -1

       if rightmark < leftmark:
           done = True
       else:
           temp = alist[leftmark]
           alist[leftmark] = alist[rightmark]
           alist[rightmark] = temp

   temp = alist[first]
   alist[first] = alist[rightmark]
   alist[rightmark] = temp


   return rightmark

alist = [54,26,93,17,77,31,44,55,20]
quickSort(alist)
print(alist)
# Out:
# [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %%
long_list = list(random.sample(range(1000000), 10000))

# %%
quickSort(long_list)

# %%
print(long_list)
# Out:
# [213, 308, 387, 405, 459, 650, 722, 767, 1015, 1087, 1147, 1215, 1237, 1247, 1259, 1274, 1555, 1859, 2044, 2405, 2522, 2570, 2638, 2670, 2678, 2775, 2876, 2943, 3034, 3229, 3243, 3506, 3638, 3811, 3849, 4490, 4509, 4607, 4791, 5015, 5129, 5140, 5180, 5253, 5394, 5427, 5730, 5770, 5773, 5787, 6105, 6125, 6221, 6229, 6498, 6531, 6566, 6698, 6730, 6779, 6875, 6897, 7160, 7307, 7486, 7660, 7707, 7743, 7758, 7824, 7883, 7917, 8031, 8071, 8226, 8242, 8501, 8529, 8744, 8784, 8802, 8898, 8940, 8978, 9082, 9136, 9148, 9153, 9384, 9421, 9702, 9853, 10199, 10251, 10383, 10399, 10545, 10579, 10589, 10622, 10797, 10835, 11079, 11099, 11110, 11132, 11166, 11340, 11396, 11443, 11520, 11521, 11582, 11585, 11616, 11620, 11810, 11840, 11982, 12068, 12096, 12125, 12249, 12275, 12306, 12341, 12451, 12566, 12751, 12757, 12761, 12934, 12959, 12980, 13011, 13047, 13131, 13266, 13468, 13492, 13524, 13626, 13664, 13685, 13739, 13963, 14093, 14263, 14312, 14407, 14579, 14783, 14890, 14949, 15003, 15081, 15145, 15208, 15415, 15431, 15491, 15698, 15727, 15942, 16335, 16340, 16348, 16351, 16428, 16434, 16523, 16636, 16722, 16751, 16847, 17005, 17102, 17134, 17172, 17271, 17362, 17401, 17802, 17831, 17837, 17927, 17945, 17951, 18032, 18060, 18066, 18233, 18252, 18279, 18309, 18512, 18585, 18594, 18716, 18754, 18766, 18883, 18914, 19067, 19164, 19188, 19311, 19370, 19453, 19504, 19790, 19872, 19913, 20046, 20096, 20131, 20410, 20437, 20448, 20454, 20474, 20506, 20545, 20598, 20755, 20799, 20844, 20880